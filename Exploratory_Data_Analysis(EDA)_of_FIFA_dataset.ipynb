# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham-hub/EDA-of-FIFA-dataset/blob/main/Exploratory_Data_Analysis(EDA)_of_FIFA_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
fifa = pd.read_csv('/content/drive/MyDrive/EDA Projects /Exploratory Data Analysis(EDA) of FIFA dataset/players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
#
# [5 rows x 104 columns]

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
for col in fifa.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color='g')
plt.title('Distribution of players for top 5 country')
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary = player_salary.sort_values(by='wage_eur',ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(10,6))
plt.bar(list(player_salary['short_name'][0:5]),list(player_salary['wage_eur'][0:5]),color=['red','blue','yellow','green','purple'])
plt.show()

# %%
#german
germany = fifa[fifa['nationality']=='Germany']
germany.head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...  ...   NaN   NaN
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...  ...  55+3  64+3
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...  ...  84+3  78+3
#
# [5 rows x 104 columns]

# %%
germany.sort_values(by='height_cm',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...  ...  43+2  44+2
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...  ...  47+2  39+2
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
#
# [5 rows x 104 columns]

# %%
germany.sort_values(by='weight_kg',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...  ...  83+2  75+2
#
# [5 rows x 104 columns]

# %%
germany.sort_values(by='wage_eur',ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...  ...  52+2  61+2
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...  ...  72+3  74+3
# 70      189596  https://sofifa.com/player/189596/thomas-muller...  ...  62+3  67+3
#
# [5 rows x 104 columns]

# %%
germany[['short_name','wage_eur']].sort_values(by='wage_eur',ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
#shooting
player_shooting = fifa[['short_name','shooting']]

# %%
player_shooting.sort_values(by='shooting',ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#defending
player_defending = fifa[['short_name','defending']]

# %%
player_defending.sort_values(by='defending',ascending=False).head()
# Out:
#       short_name  defending
# 16  G. Chiellini       90.0
# 7    V. van Dijk       90.0
# 11  K. Koulibaly       89.0
# 35      D. Godín       89.0
# 49    M. Hummels       89.0

# %%
#real_madrid
real_madrid=fifa[fifa['club']=='Real Madrid']

# %%
real_madrid.sort_values(by='wage_eur',ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 46     165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...  ...  66+3  70+3
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...  ...  57+3  62+3
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 46      165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...  ...  47+2  51+2
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...  ...  84+3  79+3
# 76      201535  https://sofifa.com/player/201535/raphael-varan...  ...  83+3  77+3
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...  ...  80+3  83+3
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...  ...  79+2  78+2
#
# [5 rows x 104 columns]

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Wales                  1
# Serbia                 1
# Colombia               1
# Germany                1
# Dominican Republic     1
# Costa Rica             1
# Uruguay                1
# Japan                  1
# Croatia                1
# Name: nationality, dtype: int64
